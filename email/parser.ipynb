# %% [markdown]
# ## Import Standard Packages

# %%
import os, base64, pickle, re
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import Google Packages

# %%
from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

# %% [markdown]
# ## ENV Variables

# %%
SCOPES = ["https://www.googleapis.com/auth/gmail.readonly"]
CLIENT_SECRET_PATH = os.path.expanduser("XXX.json")  # Update path if needed
TOKEN_PATH = os.path.expanduser("~/Desktop/Auth/token.json")

# %% [markdown]
# ## Parsing/AUTH Functions

# %%
def auth_gmail():
    creds = None
    if os.path.exists(TOKEN_PATH):
        creds = Credentials.from_authorized_user_file(TOKEN_PATH,SCOPES)

    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            print("## REFRESH EXPIRED TOKEN ##")
            creds.refresh(Request())
        else:
            print("## OAUTH FLOW AUTH ##")
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRET_PATH,SCOPES)
            creds = flow.run_local_server(port=0)

        with open(TOKEN_PATH,'w') as token:
            token.write(creds.to_json())

    print(f"## TOKEN SAVED TO {TOKEN_PATH} ##")
    return creds

# %%
def search_emails(service,phrase,sender,max_results=10000):
    # Including archived emails, there are ~9000 emails in my account
    query = f'from:{sender}'
    results = service.users().messages().list(userId='me',q=query,maxResults=max_results).execute()
    messages = results.get('messages',[])
    matching_list = []
    for msg in messages:
        msg_id = msg['id']
        message = service.users().messages().get(userId='me',id=msg_id).execute()
        headers = message['payload']['headers']
        header_dict = {h['name']:h['value'] for h in headers}

        body = "NONE"
        if "parts" in message['payload']:
            for part in message['payload']['parts']:
                if part['mimeType'] == "text/plain":
                    body = base64.urlsafe_b64decode(part['body']['data']).decode()
        
        if any(phrase.lower() in value.lower() for value in header_dict.values()):
            matching_list.append({
                "From": header_dict.get("From","Unknown"),
                "Subject": header_dict.get("Subject","No Subject"),
                "Message ID": msg_id,
                "Body":body
            })
    print(f'{len(matching_list)} SUBJECTS FOUND MATCHING \"{phrase}\"')
    return matching_list

# %%
def parse_emails(email_body):
    parsed_data = {
        "Crime Type":"N/A",
        "Date":"N/A",
        "Time":"N/A",
        "Location":"N/A",
        "Incident Description":"N/A",
        "Vehicle Description":"N/A",
        "Age":"N/A",
        "Eye Color":"N/A",
        "Hair Color":"N/A",
        "Height":"N/A",
        "Race":"N/A",
        "Sex":"N/A",
        "Weight":"N/A",
        "Additional Description":"N/A",
        "Weapon":"N/A"
    }

    crime_type_match = re.search(r"Reported Offense:\s*([\w\s-]+?)(?:Date & Time|$)",email_body)
    if crime_type_match:
        parsed_data["Crime Type"] = crime_type_match.group(1).strip()
    
    date_time_match = re.search(r"Date & Time of Occurrence:\s*(\d{2}/\d{2}/\d{4})\s*(\d{1,2}:\d{2}\s*[apAP]\.?m\.?)?",email_body)
    if date_time_match:
        parsed_data["Date"] = date_time_match.group(1)
        parsed_data["Time"] = date_time_match.group(2) if date_time_match.group(2) else "N/A"

    location_match = re.search(r"Location:\s*(.+)",email_body)
    if location_match:
        location_text = location_match.group(1).strip()
        if "Report Number" in location_text:
            location_text = location_text.split("Report Number")[0].strip()
        parsed_data["Location"] = location_text
    
    incident_desc_match = re.search(r"Incident Description:\s*(.+)",email_body)
    if incident_desc_match:
        parsed_data["Incident Description"] = incident_desc_match.group(1).strip()

    vehicle_desc_match = re.search(r"Vehicle Description:\s*(.+)",email_body)
    if vehicle_desc_match:
        parsed_data["Vehicle Description"] = vehicle_desc_match.group(1).strip()

    details = {
        "Age":r"Age:\s*(\d{1,2})",
        "Eye Color":r"Eye Color:\s*(.+)",
        "Hair Color":r"Hair Color:\s*(.+)",
        "Height":r"Height:\s*(\d{1,2}\s*feet\s*\d{1,2}\s*inches)",
        "Race":r"Race:\s*(.+)",
        "Sex":r"Sex:\s*(Male|Female|Other)",
        "Weight":r"Weight:\s*(.+)",
        "Additional Description":r"Additional Description:\s*(.+)",
        "Weapon":r"Weapon:\s*(.+)"
    }

    for key, pattern in details.items():
        match = re.search(pattern,email_body)
        if match:
            parsed_data[key] = match.group(1).strip()

    parsed_data = {key: ("N/A" if value in ["None","Unknown"] else value) for key, value in parsed_data.items()}
    
    return parsed_data

# %% [markdown]
# ## Workflow

# %%
creds = auth_gmail()
# Out:
# ## TOKEN SAVED TO /home/aly/Desktop/Auth/token.json ##

# %%
service = build('gmail','v1',credentials=creds)

# %%
emails = search_emails(service,"Crime Alert","uscpublicsafety@msg.adm.usc.edu")
# Out:
# 155 SUBJECTS FOUND MATCHING "Crime Alert"

# %%
parsed_emails = []
for email in emails:
    temp = parse_emails(email['Body'])
    temp['From'] = email['From']
    temp['Subject'] = email['Subject']
    temp['Message ID'] = email['Message ID']
    parsed_emails.append(temp)

parsed_data = pd.DataFrame(parsed_emails)

# %%
parsed_data
# Out:
#              Crime Type        Date        Time  \
# 0    Aggravated Assault  03/02/2025  11:05 a.m.
# 1                   N/A  02/27/2025   4:56 p.m.
# 2               Robbery  02/25/2025   8:49 a.m.
# 3              Burglary  02/20/2025   3:55 a.m.
# 4                   N/A  02/19/2025   5:30 a.m.
# ..                  ...         ...         ...
# 150            Burglary  08/28/2022         N/A
# 151            Burglary  08/26/2022    10:30 pm
# 152             Robbery  08/22/2022   4:00 p.m.
# 153                 N/A  08/21/2022         N/A
# 154             Robbery  08/17/2022         N/A
#
#                                               Location  \
# 0    Northeast corner of Jefferson Boulevard & McCl...
# 1    At the intersection of 28th Street & Hoover St...
# 2    At the intersection of 30th Street & Hoover St...
# 3                   UPC Troy Hall at 3025 Royal Street
# 4      Off UPC campus in the 1200 block of 30th Street
# ..                                                 ...
# 150                      2600 block of Portland Street
# 151              2617 Menlo Ave. Los Angeles CA, 90007
# 152  Adjacent to campus at the southeast corner of ...
# 153                      2300 block of Portland Street
# 154             600 block West 28th Street-South Alley
#
#                                   Incident Description Vehicle Description  \
# 0    The suspect brandished a knife at the victim. ...        Teal bicycle
# 1    The suspect ran up behind the victim and grope...                 N/A
# 2    The suspect snatched the victim's phone from t...                 N/A
# 3    The Department of Public Safety received a del...                 N/A
# 4    While the victim was asleep, the suspect enter...                 N/A
# ..                                                 ...                 ...
# 150  Two suspects gained access to an apartment com...                 N/A
# 151  The suspect(s) entered the rear of the residen...                 N/A
# 152  The suspect, riding a skateboard, rode past a ...                 N/A
# 153  A student, who was asleep in bed, was awakened...                 N/A
# 154  The victim, a USC student, was walking in the ...                 N/A
#
#      Age Eye Color        Hair Color           Height      Race   Sex  \
# 0     39       N/A              Gray  5 feet 6 inches       N/A  Male
# 1     39     Brown  Short brown hair  5 feet 5 inches  Hispanic  Male
# 2     25       N/A   Dark short hair  5 feet 7 inches  Hispanic  Male
# 3     25     Brown        Dark brown              N/A  Hispanic  Male
# 4    N/A       N/A               N/A              N/A  Hispanic  Male
# ..   ...       ...               ...              ...       ...   ...
# 150   25       N/A             Black              N/A  Hispanic  Male
# 151  N/A       N/A               N/A              N/A       N/A   N/A
# 152   20       N/A           unknown              N/A     White  Male
# 153   25   unknown           unknown              N/A  Hispanic  Male
# 154   30   unknown             black              N/A     Black  Male
#
#            Weight                             Additional Description  \
# 0      Slim build  Wearing a plaid shirt, black pants, black shoe...
# 1    Medium build  Wearing black t-shirt and dark sweatpants or j...
# 2      Slim build               Wearing a blue shirt and blue jeans.
# 3      Slim build  Wearing beige cargo pants, white shoes, and a ...
# 4    Medium build  Wearing a black beanie, black sweatshirt, gray...
# ..            ...                                                ...
# 150           N/A  Black hooded sweatshirt with white letters. On...
# 151           N/A                                                N/A
# 152           N/A  Wearing a white T-shirt, jeans, black Converse...
# 153       unknown                Black long sleeve shirt, dark pants
# 154           180                         Maroon sweater, blue jeans
#
#              Weapon                                               From  \
# 0             Knife  USC Department of Public Safety <uscpublicsafe...
# 1               N/A  USC Department of Public Safety <uscpublicsafe...
# 2               N/A  USC Department of Public Safety <uscpublicsafe...
# 3               N/A  USC Department of Public Safety <uscpublicsafe...
# 4               N/A  USC Department of Public Safety <uscpublicsafe...
# ..              ...                                                ...
# 150       No weapon  USC Department of Public Safety <uscpublicsafe...
# 151             N/A  USC Department of Public Safety <uscpublicsafe...
# 152             N/A  USC Department of Public Safety <uscpublicsafe...
# 153             N/A  USC Department of Public Safety <uscpublicsafe...
# 154  No weapon used  USC Department of Public Safety <uscpublicsafe...
#
#                                              Subject        Message ID
# 0    Timely Warning Crime Alert - Aggravated Assault  19558e0be8cd7c02
# 1              Crime Alert - Sexual Battery/Fondling  1954a92157ad3085
# 2               Timely Warning Crime Alert - Robbery  1953e62c1b20aab1
# 3              Timely Warning Crime Alert - Burglary  19524e109810f11f
# 4      Crime Alert -  Burglary & Motor Vehicle Theft  1951fc48caee7216
# ..                                               ...               ...
# 150            Timely Warning Crime Alert - Burglary  182e5aa22b77b0ac
# 151                           Crime Alert - Burglary  182e1ccbacf6c9c5
# 152             Timely Warning Crime Alert - Robbery  182c8202fd7a6051
# 153            Crime Alert - Sexual Battery/Fondling  182c17427dd24629
# 154             Timely Warning Crime Alert - Robbery  182adb0036465455
#
# [155 rows x 18 columns]
